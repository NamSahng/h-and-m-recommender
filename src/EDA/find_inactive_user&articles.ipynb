# %%
import os
import gc

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm import tqdm
from scipy.optimize import curve_fit
from joblib import dump, load
import scipy.stats as stats
tqdm.pandas()

import sys
sys.path.insert(0, '../')

from utils.preprocess import *

# %%
folder = '../../data/'

articles = pd.read_csv(os.path.join(folder, "articles.csv"))
customers = pd.read_csv(os.path.join(folder, "customers.csv"))
transactions = pd.read_csv(os.path.join(folder, "transactions_train.csv"))

transactions = make_weeknum_col(transactions)
# week_num 0 is latest week of the transaction
tr_train, tr_val = split_train_valid(transactions, 0)
# tr_val = valid2submission(tr_val)

# %%
transactions.

# %%
tr_val
# Out:
#                t_dat                                        customer_id  \
# 31548013  2020-09-16  000fb6e772c5d0023892065e659963da90b1866035558e...
# 31548014  2020-09-16  000fb6e772c5d0023892065e659963da90b1866035558e...
# 31548015  2020-09-16  000fb6e772c5d0023892065e659963da90b1866035558e...
# 31548016  2020-09-16  0010e8eb18f131e724d6997909af0808adbba057529edb...
# 31548017  2020-09-16  0010e8eb18f131e724d6997909af0808adbba057529edb...
# ...              ...                                                ...
# 31788319  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788320  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788321  2020-09-22  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# 31788322  2020-09-22  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 31788323  2020-09-22  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#           article_id     price  sales_channel_id  week_num
# 31548013   786022008  0.048441                 2         0
# 31548014   913272003  0.032288                 2         0
# 31548015   889669006  0.056508                 2         0
# 31548016   237347060  0.033881                 1         0
# 31548017   562245001  0.013542                 1         0
# ...              ...       ...               ...       ...
# 31788319   929511001  0.059305                 2         0
# 31788320   891322004  0.042356                 2         0
# 31788321   918325001  0.043203                 1         0
# 31788322   833459002  0.006763                 1         0
# 31788323   898573003  0.033881                 2         0
#
# [240311 rows x 6 columns]
